# %% [markdown]
# # Black Friday:
#
# Black Friday is an informal name for the Friday following Thanksgiving Day in the United States, which is celebrated on the fourth Thursday of November. The day after Thanksgiving has been regarded as the beginning of America's Christmas shopping season since 1952, although the term "Black Friday" didn't become widely used until more recent decades.
#
# Black Friday has routinely been the busiest shopping day of the year in the United States since 2005,although news reports, which at that time were inaccurate,have described it as the busiest shopping day of the year for a much longer period of time. Similar stories resurface year upon year at this time, portraying hysteria and shortage of stock, creating a state of positive feedback.

# %%
#importing required libraries for data analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(2, 2)
# %matplotlib inline

# %%
#importing the data into a variable called Black_friday
black_friday=pd.read_csv('BlackFriday.csv')

# %%
black_friday.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#importing original file into duplicate file so that we need not to worry about original data
df=black_friday.copy()

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
# User_ID                       537577 non-null int64
# Product_ID                    537577 non-null object
# Gender                        537577 non-null object
# Age                           537577 non-null object
# Occupation                    537577 non-null int64
# City_Category                 537577 non-null object
# Stay_In_Current_City_Years    537577 non-null object
# Marital_Status                537577 non-null int64
# Product_Category_1            537577 non-null int64
# Product_Category_2            370591 non-null float64
# Product_Category_3            164278 non-null float64
# Purchase                      537577 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.columns=df.columns.map(str.lower)

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'gender', 'age', 'occupation', 'city_category',
#        'stay_in_current_city_years', 'marital_status', 'product_category_1',
#        'product_category_2', 'product_category_3', 'purchase'],
#       dtype='object')

# %%
df.head()
# Out:
#    user_id product_id gender   age  occupation city_category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   stay_in_current_city_years  marital_status  product_category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    product_category_2  product_category_3  purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df=df.fillna('0')

# %%
df.isnull().sum()
# Out:
# user_id                       0
# product_id                    0
# gender                        0
# age                           0
# occupation                    0
# city_category                 0
# stay_in_current_city_years    0
# marital_status                0
# product_category_1            0
# product_category_2            0
# product_category_3            0
# purchase                      0
# dtype: int64

# %%
df.duplicated(['user_id','product_category_1','product_category_2','product_category_3'],keep='first').value_counts()
# Out:
# True     320165
# False    217412
# dtype: int64

# %%
df.drop_duplicates(['user_id','product_category_1','product_category_2','product_category_3'],keep='first',inplace=True)

# %%
df.duplicated(['user_id','product_category_1','product_category_2','product_category_2','product_category_3'],keep='first').value_counts()
# Out:
# False    217412
# dtype: int64

# %%
#making two dataframes for male and female customers for a better visualization
m=df[df.gender=='M']
f=df[df.gender=='F']

# %% [markdown]
# # Gender age Ratio

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
m.groupby('age')['user_id'].nunique().plot.pie(autopct='%1.0f%%',
                                              wedgeprops={'linewidth':2,'edgecolor':'w'},
                                              shadow=True,
                                              colors=['green','blue']);
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('Male age Ratio',fontsize=30);

plt.subplot(122)
f.groupby('age')['user_id'].nunique().plot.pie(autopct='%1.0f%%',
                                              wedgeprops={'linewidth':2,'edgecolor':'w'},
                                              shadow=True,
                                              colors=['blue','grey'])
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('Female age Ratio',fontsize=30);

# %% [markdown]
# comaprison of age ratio for male and female:
#
#
# 0-17 age group in male is 3% where female is 5%.
#
#
# 18-25 age group in male is 19% where female is 17%.
#
#
# 26-35 age group in male is 36% where female is 33%.
#
#
# 36-45 age group in male and female is 20%.
#
#
# 46-50 age group in male is 8% where female is 11%.
#
#
# 51-55 age group in male is 8% where female is 9%.
#
#
# 55+ of age group in male and female is 6%.
#
# conclusion:
# maximum population age group on black friday is 26-25 and medium population age group on black friday is 36-45.

# %% [markdown]
# # Gender age ratio according to Occupation

# %%
plt.figure(figsize=(20,30))
plt.subplot(221)
m.groupby('age')['occupation'].nunique().plot.pie(autopct='%1.0f%%',
                                                 wedgeprops={'linewidth':2,'edgecolor':'white'},
                                                 shadow=True,
                                                 colors=['green','blue'])
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('Male age ratio according to occupation',fontsize=20);

plt.subplot(222)
f.groupby('age')['occupation'].nunique().plot.pie(autopct='%1.0f%%',
                                                 wedgeprops={'linewidth':2,'edgecolor':'white'},
                                                 shadow=True,
                                                 colors=['blue','grey'])
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='White')
plt.gca().add_artist(circle)
plt.title('Female age ratio according to occupation',fontsize=20);

# %% [markdown]
# # Gender Count according to City Categories:

# %%
plt.figure(figsize=(25,20))
plt.subplot(221)
sns.countplot('city_category',data=m);
plt.ylabel('Count',fontsize=20)
plt.xlabel('City Category',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Count of Male City Category',fontsize=20)

plt.subplot(222)
sns.countplot('city_category',data=f)
plt.ylabel('Count',fontsize=20)
plt.xlabel('City Category',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Count of Male City Category',fontsize=20);
plt.subplots_adjust(wspace = .3)

# %% [markdown]
# # Count on Gender's Martial Status:

# %%
plt.figure(figsize=(30,20))
plt.subplot(221)
ax=sns.countplot('marital_status',data=f,palette='rainbow');
plt.ylabel('count',fontsize=20)
plt.xlabel('Marital Status',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Female Martial Status',fontsize=20)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+p.get_width()/2,p.get_height()),
               ha='center',va='center',xytext=(0,10),textcoords='offset points',color='black',fontsize=15)

plt.subplot(222)
ax=sns.countplot('marital_status',data=m,palette=['blue','green']);
plt.ylabel('count',fontsize=20)
plt.xlabel('Marital Status',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Male Martial Status',fontsize=20);
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+p.get_width()/2,p.get_height()),
               ha='center',va='center',xytext=(0,10),textcoords='offset points',color='black',fontsize=15)

plt.subplots_adjust(wspace=.3)

# %% [markdown]
# # Each city category Gender ratio

# %%
a=df[df.city_category=='A']
b=df[df.city_category=='B']
c=df[df.city_category=='C']

# %%
fig=plt.figure(figsize=(20,20))
fig.add_subplot(gs[0, 0])
a.groupby('gender')['city_category'].nunique().plot.pie(autopct='%1.0f%%',
                                      wedgeprops={'linewidth':2,'edgecolor':'white'},
                                      shadow=True,
                                      colors=['blue','green']);
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('A city category Gender ratio',fontsize=20)

fig.add_subplot(gs[0, 1])
b.groupby('gender')['city_category'].nunique().plot.pie(autopct='%1.0f%%',
                                      wedgeprops={'linewidth':2,'edgecolor':'white'},
                                      shadow=True,
                                      colors=['yellow','green']);
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('B City category gender ratio',fontsize=20)

fig.add_subplot(gs[1, :])
c.groupby('gender')['city_category'].nunique().plot.pie(autopct='%1.0f%%',
                                      wedgeprops={'linewidth':2,'edgecolor':'white'},
                                      shadow=True,
                                      colors=['orange','green']);
plt.ylabel('')
circle=plt.Circle((0,0),0.7,color='white')
plt.gca().add_artist(circle)
plt.title('C city category gender ratio',fontsize=20);

# %%
df.head(1)
# Out:
#    user_id product_id gender   age  occupation city_category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   stay_in_current_city_years  marital_status  product_category_1  \
# 0                          2               0                   3
#
#   product_category_2 product_category_3  purchase
# 0                  0                  0      8370

# %%
data_type={'product_category_2':int,'product_category_3':int}
df=df.astype(data_type)
data_type={'product_category_2':str,'product_category_3':str}
df=df.astype(data_type)

# %%
p1=df[df.product_category_1!=0]
p2=df[df.product_category_2!='0']
p3=df[df.product_category_3!='0']

# %% [markdown]
# # Purchase under Product Category 1 according to gender

# %%
plt.figure(figsize=(20,10))
sns.countplot('product_category_1',data=df,hue='gender',palette=['green','blue'])
plt.xlabel('Product Category 1',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper right',prop={'size':20})
plt.title('Purchase under Product Category 1 according to gender',fontsize=20);

# %% [markdown]
# # Purchase under Product Category 2 according to gender

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=p2.product_category_2,data=df,hue='gender',palette='Accent')
plt.xlabel('Product Category 2',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left',prop={'size':20})
plt.title('Purchase under Product Category 2 according to gender',fontsize=20);

# %% [markdown]
# # Purchase under Product Category 3 according to gender

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=p3.product_category_3,data=df,hue='gender',palette='Paired')
plt.xlabel('Product Category 3',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(loc='upper left',prop={'size':20})
plt.title('Purchase under Product Category 3 according to gender',fontsize=20);

# %% [markdown]
# # Total purchase made according to genders

# %%
purchase=df.groupby('gender')['purchase'].sum().reset_index()
plt.figure(figsize=(15,9))
ax=sns.barplot(x='gender',y='purchase',data=purchase,palette=['red','green'])
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()),
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points',color='black',fontsize=15)
plt.ylabel('Gender',fontsize=15)
plt.xlabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Total purchase made according to genders',fontsize=15);

# %% [markdown]
# # Female Purchase according to the age groups

# %%
plt.figure(figsize=(15,9))
fp=f.groupby('age')['purchase'].sum().reset_index()
ax=sns.barplot(x='age',y='purchase',data=fp,palette='rainbow')
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+p.get_width()/2,p.get_height()),
               ha='center',va='center',xytext=(0,10),textcoords='offset points',color='black',fontsize=15)
plt.xlabel('Age',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Female Purchase according to the age groups',fontsize=15);

# %% [markdown]
# # Male purchase according to the Age group

# %%
plt.figure(figsize=(15,9))
mp=m.groupby('age')['purchase'].sum().reset_index()
ax=sns.barplot(x='age',y='purchase',data=mp,palette='rainbow')
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+p.get_width()/2,p.get_height()),
               ha='center',va='center',xytext=(0,10),textcoords='offset points',color='black',fontsize=15)
plt.xlabel('Age',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Male purchase according to the Age group',fontsize=15);

# %%
df.product_category_2=df.product_category_2.str.replace('.0','')
df.product_category_3=df.product_category_3.str.replace('.0','')

# %% [markdown]
# # Purchase Comparison according to Marital Status

# %%
plt.figure(figsize=(20,9))
pm=df.groupby('marital_status')['purchase'].sum().reset_index()
ax=sns.barplot(x='marital_status',y='purchase',data=pm)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+p.get_width()/2,p.get_height()),
               ha='center',va='center',xytext=(0,10),textcoords='offset points',color='black',fontsize=15)
plt.xlabel('Marital Status',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Purchase Comparison according to Marital Status',fontsize=15);

# %% [markdown]
# # Male Purchase according to Marital status

# %%
plt.figure(figsize=(20,9))
plt.subplot(121)
sns.boxplot(x='marital_status',y='purchase',data=m,palette=['red','blue'])
plt.xlabel('Marital Status',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Female Purchase according to Marital status',fontsize=15)

plt.subplot(122)
sns.boxplot(x='marital_status',y='purchase',data=f,palette=['green','yellow'])
plt.xlabel('Marital Status',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Male Purchase according to Marital status',fontsize=15);

# %% [markdown]
# # Comparing Gender through Purchase according to the Age

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='age',y='purchase',data=df,palette='rainbow',hue='gender')
plt.xlabel('Age',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Comparing Gender through Purchase according to the Age',fontsize=15)
plt.legend(loc='best',prop={'size':15});

# %% [markdown]
# # Female Purchase according to the Age

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x='age',y='purchase',data=f,palette='rainbow')
plt.xlabel('Age',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Female Purchase according to the Age',fontsize=15);

# %% [markdown]
# # Male Purchase according to the Age

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x='age',y='purchase',data=m,palette='rainbow')
plt.xlabel('Age',fontsize=15)
plt.ylabel('Purchase',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Male Purchase according to the Age',fontsize=15);

# %% [markdown]
# # Heatmap

# %%
cr = df.corr()
fig,ax = plt.subplots(figsize = (12,9))
sns.heatmap(cr, vmax=.8, annot=True,square=True);
